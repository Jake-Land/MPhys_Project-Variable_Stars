# %%
import os
import re
import yaml
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
with open("Star_Configurations/current_config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

# Example access:
print(cfg["main_star"])
# Out:
# HD 234063

# %%
base_dir = Path(cfg["base_dir"])
print("base_dir = "+str(base_dir))

file_object = cfg["file_object"]
print("file_object = "+str(file_object))

main_star = cfg["main_star"]
print("main_star = "+main_star)

file_nights = cfg["file_nights"].keys()
file_nights = list(file_nights)
print("file_nights = "+str(file_nights))
# Out:
# base_dir = data
# file_object = Standards_2
# main_star = HD 234063
# file_nights = ['2024_03_06']

# %%
night = file_nights[0]
print(night)

colour_list = cfg['file_nights'][str(night)]["colour_list"]
threshold_for_DAO = cfg['file_nights'][str(night)]["threshold_for_DAO"]

print(colour_list)
print(threshold_for_DAO)
# Out:
# 2024_03_06
# ['Bader_JC_B', 'Bader_JC_R', 'Bader_JC_U', 'Bader_JC_V', 'ZWO_Blue', 'ZWO_Green', 'ZWO_Red']
# 5.0

# %% [markdown]
# # Sorting data

# %%
# Prepare a list to store results
results = []

# Loop through colours and files
for colour in colour_list:
    folder = base_dir / file_object / night / "Light" / colour / "photometry"
    for file in os.listdir(folder):
        if file.endswith(".csv"):
            file_path = folder / file
            with open(file_path, "r") as f:
                row_count = sum(1 for line in f) - 1  # subtract header
            print(f"Number of stars detected in {file}: {row_count}")
            results.append({
                "filename": file,
                "colour": colour,
                "number_of_stars": row_count
            })

# Convert to DataFrame and save as CSV
results_df = pd.DataFrame(results)
# Out:
# Number of stars detected in UCAC4_Light_Bader_JC_B_187_secs_001_reduced_photometry.csv: 67
# Number of stars detected in UCAC4_Light_Bader_JC_B_30_secs_001_reduced_photometry.csv: 45
# Number of stars detected in UCAC4_Light_Bader_JC_R_187_secs_001_reduced_photometry.csv: 107
# Number of stars detected in UCAC4_Light_Bader_JC_R_30_secs_001_reduced_photometry.csv: 59
# Number of stars detected in UCAC4_Light_Bader_JC_R_75_secs_001_reduced_photometry.csv: 76
# Number of stars detected in UCAC4_Light_Bader_JC_U_187_secs_001_reduced_photometry.csv: 85
# Number of stars detected in UCAC4_Light_Bader_JC_U_30_secs_001_reduced_photometry.csv: 65
# Number of stars detected in UCAC4_Light_Bader_JC_U_467_secs_001_reduced_photometry.csv: 86
# Number of stars detected in UCAC4_Light_Bader_JC_U_75_secs_001_reduced_photometry.csv: 81
# Number of stars detected in UCAC4_Light_Bader_JC_V_187_secs_001_reduced_photometry.csv: 75
# Number of stars detected in UCAC4_Light_Bader_JC_V_30_secs_001_reduced_photometry.csv: 57
# Number of stars detected in UCAC4_Light_Bader_JC_V_75_secs_001_reduced_photometry.csv: 57
# Number of stars detected in UCAC4_Light_ZWO_Blue_187_secs_001_reduced_photometry.csv: 78
# Number of stars detected in UCAC4_Light_ZWO_Blue_30_secs_001_reduced_photometry.csv: 59
# Number of stars detected in UCAC4_Light_ZWO_Blue_467_secs_001_reduced_photometry.csv: 99
# Number of stars detected in UCAC4_Light_ZWO_Blue_75_secs_001_reduced_photometry.csv: 75
# Number of stars detected in UCAC4_Light_ZWO_Green_30_secs_001_reduced_photometry.csv: 51
# Number of stars detected in UCAC4_Light_ZWO_Green_467_secs_001_reduced_photometry.csv: 119
# Number of stars detected in UCAC4_Light_ZWO_Green_75_secs_001_reduced_photometry.csv: 49
# Number of stars detected in UCAC4_Light_ZWO_Red_187_secs_001_reduced_photometry.csv: 94
# Number of stars detected in UCAC4_Light_ZWO_Red_30_secs_001_reduced_photometry.csv: 47
# Number of stars detected in UCAC4_Light_ZWO_Red_467_secs_001_reduced_photometry.csv: 131
# Number of stars detected in UCAC4_Light_ZWO_Red_75_secs_001_reduced_photometry.csv: 69

# %%
output_path = base_dir / file_object / night / "star_counts" / f"star_counts_threshold_{threshold_for_DAO}.csv"
results_df.to_csv(output_path, index=False)

# %% [markdown]
# # Plotting

# %%
folder_path = base_dir / file_object / night / "star_counts"

all_dataframes = []

for file in os.listdir(folder_path):
    if file.endswith(".csv") and "star_counts_threshold_" in file:
        file_path = folder_path / file

        # Extract threshold value
        threshold_match = re.search(r"star_counts_threshold_(\d+\.?\d*)", file)
        threshold = float(threshold_match.group(1)) if threshold_match else None

        # Read CSV
        file_df = pd.read_csv(file_path)

        # Extract exposure ID from each filename in the CSV
        exposure_ids = file_df["filename"].str.extract(r"_(\d+)_secs")[0]
        file_df["exposure_id"] = exposure_ids.astype(str)

        # Add threshold column
        file_df["threshold"] = threshold

        all_dataframes.append(file_df)

# Combine all into one DataFrame
combined_df = pd.concat(all_dataframes, ignore_index=True)

# %%
for selected_filter in colour_list:

    # Filter the DataFrame
    df_filtered = combined_df[combined_df["colour"] == selected_filter]
    
    # Group by exposure and threshold, then average
    df_avg = (
        df_filtered
        .groupby(["exposure_id", "threshold"], as_index=False)
        .agg({"number_of_stars": "mean"})
    )
    
    # Plot: one line per exposure time
    plt.figure(figsize=(10, 6))
    
    for exposure, group in df_avg.groupby("exposure_id"):
        sorted_group = group.sort_values("threshold")
        plt.plot(
            sorted_group["threshold"],
            sorted_group["number_of_stars"],
            marker="o",
            label=f"{exposure} seconds"
        )
    
    plt.title(f"Stars Detected vs Threshold for Filter: {selected_filter}")
    plt.xlabel("Detection Threshold (σ)")
    plt.ylabel("Number of Stars Detected")
    plt.legend(title="Exposure Time")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
